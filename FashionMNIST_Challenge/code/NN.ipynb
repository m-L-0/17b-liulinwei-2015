# %%
# 不含隐层的神经网络， 输入层是784个神经元 输出层是10个神经元
import  tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data


#载入数据集
mnist = input_data.read_data_sets("../data/fashion", one_hot=True)
#每个批次的大小
batch_size = 100
#计算一共有多少个批次
n_batch =  mnist.train.num_examples // batch_size

#定义两个placeholder
x = tf.placeholder(tf.float32, [None,784]) #输入图像
y = tf.placeholder(tf.float32, [None,10]) #输入标签

#创建一个简单的神经网络 784个像素点对应784个数  因此输入层是784个神经元 输出层是10个神经元 不含隐层 
#最后准确率在92%左右
W = tf.Variable(tf.zeros([784,10])) #生成784行 10列的全0矩阵
b = tf.Variable(tf.zeros([1,10])) 
prediction = tf.nn.softmax(tf.matmul(x,W)+b)

#二次代价函数
loss = tf.reduce_mean(tf.square(y-prediction))
#使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#初始化变量
init = tf.global_variables_initializer()

#结果存放在布尔型列表中
#argmax能给出某个tensor对象在某一维上的其数据最大值所在的索引值
correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(prediction,1))
#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))
with tf.Session() as sess:
    sess.run(init)
    for epoch in range(21): #21个epoch 把所有的图片训练21次
        for batch in range(n_batch): #
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images, y:mnist.test.labels})
        print("Iter " + str(epoch) + ",Testing Accuracy " + str(acc))
# Out:
# Extracting ../data/fashion/train-images-idx3-ubyte.gz
# Extracting ../data/fashion/train-labels-idx1-ubyte.gz
# Extracting ../data/fashion/t10k-images-idx3-ubyte.gz
# Extracting ../data/fashion/t10k-labels-idx1-ubyte.gz
# Iter 0,Testing Accuracy 0.7118
# Iter 1,Testing Accuracy 0.7701
# Iter 2,Testing Accuracy 0.7861
# Iter 3,Testing Accuracy 0.7983
# Iter 4,Testing Accuracy 0.8045
# Iter 5,Testing Accuracy 0.809
# Iter 6,Testing Accuracy 0.8128
# Iter 7,Testing Accuracy 0.8175
# Iter 8,Testing Accuracy 0.8192
# Iter 9,Testing Accuracy 0.8205
# Iter 10,Testing Accuracy 0.8224
# Iter 11,Testing Accuracy 0.822
# Iter 12,Testing Accuracy 0.8247
# Iter 13,Testing Accuracy 0.8257
# Iter 14,Testing Accuracy 0.8268
# Iter 15,Testing Accuracy 0.8274
# Iter 16,Testing Accuracy 0.8293
# Iter 17,Testing Accuracy 0.8288
# Iter 18,Testing Accuracy 0.8308
# Iter 19,Testing Accuracy 0.8296
# Iter 20,Testing Accuracy 0.8322

# %%
# 含一个隐层的神经网络，输入层是784个神经元，两个隐层都是100个神经元，输出层是10个神经元
import  tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data


#载入数据集
mnist = input_data.read_data_sets("../data/fashion", one_hot=True)
#每个批次的大小
batch_size = 50
#计算一共有多少个批次
n_batch =  mnist.train.num_examples // batch_size

#定义两个placeholder
x = tf.placeholder(tf.float32, [None,784]) #输入图像
y = tf.placeholder(tf.float32, [None,10]) #输入标签


#定义神经网络中间层
Weights_L1 = tf.Variable(tf.random_normal([784,100]))
biase_L1 = tf.Variable(tf.zeros([1,100])) 
Wx_plus_b_L1 = tf.matmul(x, Weights_L1)+biase_L1 
L1 = tf.nn.tanh(Wx_plus_b_L1) #使用正切函数作为激活函数 

Weights_L2 = tf.Variable(tf.random_normal([100,100]))
biase_L2 = tf.Variable(tf.zeros([1,100])) 
Wx_plus_b_L2 = tf.matmul(L1, Weights_L2)+biase_L2 
L2 = tf.nn.tanh(Wx_plus_b_L2) #使用正切函数作为激活函数 

#定义神经网络输出层
Weights_L3 = tf.Variable(tf.random_normal([100,10]))
biase_L3 = tf.Variable(tf.zeros([1,10]))
Wx_plus_b_L3 = tf.matmul(L2,Weights_L3) + biase_L3
prediction = tf.nn.tanh(Wx_plus_b_L3)

#二次代价函数
loss = tf.reduce_mean(tf.square(y-prediction))
#使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#初始化变量
init = tf.global_variables_initializer()

#结果存放在布尔型列表中
#argmax能给出某个tensor对象在某一维上的其数据最大值所在的索引值
correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(prediction,1))
#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))
with tf.Session() as sess:
    sess.run(init)
    for epoch in range(500): 
        for batch in range(n_batch):             
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images, y:mnist.test.labels}) 
        print ("Iter " + str(epoch) + ",Testing Accuracy " + str(acc))
# Out:
# Extracting ../data/fashion/train-images-idx3-ubyte.gz
# Extracting ../data/fashion/train-labels-idx1-ubyte.gz
# Extracting ../data/fashion/t10k-images-idx3-ubyte.gz
# Extracting ../data/fashion/t10k-labels-idx1-ubyte.gz
# Iter 0,Testing Accuracy 0.2497
# Iter 1,Testing Accuracy 0.2226
# Iter 2,Testing Accuracy 0.1395
# Iter 3,Testing Accuracy 0.1431
# Iter 4,Testing Accuracy 0.1122
# Iter 5,Testing Accuracy 0.1201
# Iter 6,Testing Accuracy 0.1169
# Iter 7,Testing Accuracy 0.1679
# Iter 8,Testing Accuracy 0.2021
# Iter 9,Testing Accuracy 0.2112
# Iter 10,Testing Accuracy 0.2042
# Iter 11,Testing Accuracy 0.1595
# Iter 12,Testing Accuracy 0.2048
# Iter 13,Testing Accuracy 0.2064
# Iter 14,Testing Accuracy 0.2017
# Iter 15,Testing Accuracy 0.2049
# Iter 16,Testing Accuracy 0.2033
# Iter 17,Testing Accuracy 0.2075
# Iter 18,Testing Accuracy 0.1921
# Iter 19,Testing Accuracy 0.1122
# Iter 20,Testing Accuracy 0.1908
# Iter 21,Testing Accuracy 0.2117
# Iter 22,Testing Accuracy 0.1918
# Iter 23,Testing Accuracy 0.211
# Iter 24,Testing Accuracy 0.2073
# Iter 25,Testing Accuracy 0.2264
# Iter 26,Testing Accuracy 0.1298
# Iter 27,Testing Accuracy 0.2126
# Iter 28,Testing Accuracy 0.1478
# Iter 29,Testing Accuracy 0.2366
# Iter 30,Testing Accuracy 0.2374
# Iter 31,Testing Accuracy 0.2448
# Iter 32,Testing Accuracy 0.1464
# Iter 33,Testing Accuracy 0.2364
# Iter 34,Testing Accuracy 0.2577
# Iter 35,Testing Accuracy 0.2594
# Iter 36,Testing Accuracy 0.1642
# Iter 37,Testing Accuracy 0.2534
# Iter 38,Testing Accuracy 0.2561
# Iter 39,Testing Accuracy 0.2473
# Iter 40,Testing Accuracy 0.2558
# Iter 41,Testing Accuracy 0.2498
# Iter 42,Testing Accuracy 0.2676
# Iter 43,Testing Accuracy 0.1846
# Iter 44,Testing Accuracy 0.2684
# Iter 45,Testing Accuracy 0.2648
# Iter 46,Testing Accuracy 0.1732
# Iter 47,Testing Accuracy 0.2608
# Iter 48,Testing Accuracy 0.2753
# Iter 49,Testing Accuracy 0.1892
# Iter 50,Testing Accuracy 0.2718
# Iter 51,Testing Accuracy 0.2628
# Iter 52,Testing Accuracy 0.1965
# Iter 53,Testing Accuracy 0.2632
# Iter 54,Testing Accuracy 0.1772
# Iter 55,Testing Accuracy 0.2704
# Iter 56,Testing Accuracy 0.269
# Iter 57,Testing Accuracy 0.2691
# Iter 58,Testing Accuracy 0.2694
# Iter 59,Testing Accuracy 0.1854
# Iter 60,Testing Accuracy 0.0994
# Iter 61,Testing Accuracy 0.2698
# Iter 62,Testing Accuracy 0.2729
# Iter 63,Testing Accuracy 0.2729
# Iter 64,Testing Accuracy 0.1796
# Iter 65,Testing Accuracy 0.1759
# Iter 66,Testing Accuracy 0.2638
# Iter 67,Testing Accuracy 0.274
# Iter 68,Testing Accuracy 0.1738
# Iter 69,Testing Accuracy 0.2705
# Iter 70,Testing Accuracy 0.2709
# Iter 71,Testing Accuracy 0.2713
# Iter 72,Testing Accuracy 0.2709
# Iter 73,Testing Accuracy 0.2712
# Iter 74,Testing Accuracy 0.2714
# Iter 75,Testing Accuracy 0.2811
# Iter 76,Testing Accuracy 0.2813
# Iter 77,Testing Accuracy 0.2712
# Iter 78,Testing Accuracy 0.2784
# Iter 79,Testing Accuracy 0.2734
# Iter 80,Testing Accuracy 0.2769
# Iter 81,Testing Accuracy 0.1975
# Iter 82,Testing Accuracy 0.2757
# Iter 83,Testing Accuracy 0.1802
# Iter 84,Testing Accuracy 0.1741
# Iter 85,Testing Accuracy 0.1816
# Iter 86,Testing Accuracy 0.2708
# Iter 87,Testing Accuracy 0.2756
# Iter 88,Testing Accuracy 0.2718
# Iter 89,Testing Accuracy 0.273
# Iter 90,Testing Accuracy 0.2732
# Iter 91,Testing Accuracy 0.2783
# Iter 92,Testing Accuracy 0.1826
# Iter 93,Testing Accuracy 0.2735
# Iter 94,Testing Accuracy 0.2762
# Iter 95,Testing Accuracy 0.2739
# Iter 96,Testing Accuracy 0.2713
# Iter 97,Testing Accuracy 0.1796
# Iter 98,Testing Accuracy 0.2752
# Iter 99,Testing Accuracy 0.1793
# Iter 100,Testing Accuracy 0.2683
# Iter 101,Testing Accuracy 0.2753
# Iter 102,Testing Accuracy 0.2729
# Iter 103,Testing Accuracy 0.2674
# Iter 104,Testing Accuracy 0.1836
# Iter 105,Testing Accuracy 0.2715
# Iter 106,Testing Accuracy 0.1989
# Iter 107,Testing Accuracy 0.1908
# Iter 108,Testing Accuracy 0.1845
# Iter 109,Testing Accuracy 0.2831
# Iter 110,Testing Accuracy 0.1823
# Iter 111,Testing Accuracy 0.2811
# Iter 112,Testing Accuracy 0.2754
# Iter 113,Testing Accuracy 0.1789
# Iter 114,Testing Accuracy 0.275
# Iter 115,Testing Accuracy 0.2754
# Iter 116,Testing Accuracy 0.2736
# Iter 117,Testing Accuracy 0.1979
# Iter 118,Testing Accuracy 0.2727
# Iter 119,Testing Accuracy 0.2811
# Iter 120,Testing Accuracy 0.2727
# Iter 121,Testing Accuracy 0.2759
# Iter 122,Testing Accuracy 0.2756
# Iter 123,Testing Accuracy 0.2779
# Iter 124,Testing Accuracy 0.2789
# Iter 125,Testing Accuracy 0.2746
# Iter 126,Testing Accuracy 0.2744
# Iter 127,Testing Accuracy 0.278
# Iter 128,Testing Accuracy 0.2756
# Iter 129,Testing Accuracy 0.27
# Iter 130,Testing Accuracy 0.1835
# Iter 131,Testing Accuracy 0.2776
# Iter 132,Testing Accuracy 0.2759
# Iter 133,Testing Accuracy 0.2719
# Iter 134,Testing Accuracy 0.1836
# Iter 135,Testing Accuracy 0.2723
# Iter 136,Testing Accuracy 0.2834
# Iter 137,Testing Accuracy 0.2785
# Iter 138,Testing Accuracy 0.2841
# Iter 139,Testing Accuracy 0.1896
# Iter 140,Testing Accuracy 0.1777
# Iter 141,Testing Accuracy 0.2707
# Iter 142,Testing Accuracy 0.2768
# Iter 143,Testing Accuracy 0.1912
# Iter 144,Testing Accuracy 0.2822
# Iter 145,Testing Accuracy 0.186
# Iter 146,Testing Accuracy 0.2802
# Iter 147,Testing Accuracy 0.2804
# Iter 148,Testing Accuracy 0.185
# Iter 149,Testing Accuracy 0.2767
# Iter 150,Testing Accuracy 0.2779
# Iter 151,Testing Accuracy 0.2763
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-414d0d48adaa> in <module>()
#      50         for batch in range(n_batch):
#      51             batch_xs,batch_ys = mnist.train.next_batch(batch_size)
# ---> 52             sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
#      53         acc = sess.run(accuracy,feed_dict={x:mnist.test.images, y:mnist.test.labels})
#      54         print ("Iter " + str(epoch) + ",Testing Accuracy " + str(acc))
#
# /home/linwei/.virtualenvs/jupyter_env3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/linwei/.virtualenvs/jupyter_env3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /home/linwei/.virtualenvs/jupyter_env3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/linwei/.virtualenvs/jupyter_env3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /home/linwei/.virtualenvs/jupyter_env3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
